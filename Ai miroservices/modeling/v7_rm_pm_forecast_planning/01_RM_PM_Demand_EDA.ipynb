# %% [markdown]
# # RM/PM Demand EDA
#
# Demand concentration, intermittency, outliers, ABC, and FMS classes.

# %%
from pathlib import Path
import json
import pandas as pd
import matplotlib.pyplot as plt

ROOT = Path.cwd()
if ROOT.name != "v7_rm_pm_forecast_planning":
    ROOT = Path("Ai miroservices/modeling/v7_rm_pm_forecast_planning").resolve()
OUT = ROOT / "outputs"
pd.set_option("display.max_columns", 80)

# %%
classes = pd.read_csv(OUT / "demand_classification.csv")
classes.head(20)
# Out:
#                              material_id  material_code  \
# 0   5571d3cd-666f-4673-a41e-efeb313da005         100036
# 1   44dd0de1-d770-4f74-bccb-e6fc16f574ca         100098
# 2   ed5d69d5-7370-4a93-b888-2aa711897187         101054
# 3   861bf563-9747-4508-96c0-5a0c976acbcd         101293
# 4   3670333e-585b-4f10-9d15-912dcb65d820         100108
# 5   584db23d-9317-457f-9e7d-d7592e043210         101580
# 6   2b39aadc-6592-406c-914f-482f4cbb7ab5         100323
# 7   9a11c556-2240-4f35-ae53-f0c8c8a88fb4         100460
# 8   e77e97bd-5de0-41f8-afc3-037acf6b900b         100050
# 9   decce9e4-20de-45c6-af1c-9d641542a43f         100714
# 10  bda6d12a-d73f-41ad-819a-138cc6a23f0a         100094
# 11  eb8ed24a-368a-4dd5-9fb8-201fcaf5d00c         101308
# 12  fff350bf-706e-4c5d-af7d-c2f6671cd62f         101399
# 13  f981186b-8e15-48e6-ac2a-5284e808d0ec         100110
# 14  713039d3-602b-4068-9826-c0a022e688a0         100403
# 15  edd99bbd-4e70-4d2d-a6ee-ed744d7d2be9         101398
# ...

# %%
classes.groupby(["abc_class", "fms_class"]).size().unstack(fill_value=0)
# Out:
# fms_class    F   M   S
# abc_class
# A           17   0   0
# B           40   0   0
# C          178  15  38

# %%
classes[["material_code", "description", "material_type", "total_demand", "abc_class", "fms_class", "nonzero_rate", "cv", "planning_priority"]].head(30)
# Out:
#     material_code                               description material_type  \
# 0          100036                              CAUSTIC SODA  raw_material
# 1          100098                                  SORBITOL  raw_material
# 2          101054              CALCIUM CARBONATE ( GROUND )  raw_material
# 3          101293      FLUFF UNTREATED - GOLDEN ISLES G4881  raw_material
# 4          100108                             TALCUM POWDER  raw_material
# 5          101580                           SODIUM SILICATE  raw_material
# 6          100323                BC COLOGNE BULK - IMPORTED  raw_material
# 7          100460                             GALAXY LES 70  raw_material
# 8          100050                                 GLYCERINE  raw_material
# 9          100714                    COCOMIDOPROPYL BETAINE  raw_material
# 10         100094                     SILICA 165 THICKENING  raw_material
# 11         101308               PE BACK SHEET 170mm - WHITE  raw_material
# ...

# %%
from IPython.display import Image
Image(filename=str(OUT / "plots" / "top_demand_materials.png"))
