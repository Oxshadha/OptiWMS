# %% [markdown]
# # 01 Classical Models (ETS, ARIMA, SARIMA)
#
# Runs baseline classical models on datasets A and B.

# %%
from pathlib import Path
import subprocess, sys

ROOT = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling')
cmd = [sys.executable, str(ROOT / 'scripts' / 'run_classical.py'), '--datasets', 'A', 'B']
print('Running:', ' '.join(cmd))
subprocess.run(cmd, check=True)
# Out:
# Running: /opt/anaconda3/envs/dashboard-project/bin/python /Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts/run_classical.py --datasets A B
# [OK] A/ETS: forecasts=618, metrics=8, inventory=103, failed_series=0
# [OK] A/ARIMA: forecasts=618, metrics=8, inventory=103, failed_series=0
# [OK] A/SARIMA: forecasts=618, metrics=8, inventory=103, failed_series=0
# [OK] B/ETS: forecasts=618, metrics=8, inventory=103, failed_series=0
# [OK] B/ARIMA: forecasts=618, metrics=8, inventory=103, failed_series=0
# [OK] B/SARIMA: forecasts=618, metrics=8, inventory=103, failed_series=0
# CompletedProcess(args=['/opt/anaconda3/envs/dashboard-project/bin/python', '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts/run_classical.py', '--datasets', 'A', 'B'], returncode=0)

# %%
import pandas as pd
from pathlib import Path

out = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/metrics')
files = sorted(out.glob('metrics_classical_*_all.csv'))
print('metric files:', [f.name for f in files])
if files:
    m = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)
    display(m[(m['split']=='test') & (m['horizon']==0)].sort_values(['dataset','WAPE']).head(20))
# Out:
# metric files: ['metrics_classical_A_all.csv', 'metrics_classical_B_all.csv']
#    dataset   model split  horizon  n_obs      WAPE         RMSE         Bias  \
# 7        A     ETS  test        0    309  0.106712  4981.780602  -182.469029
# 15       A   ARIMA  test        0    309  0.109983  5288.166760 -2154.411452
# 23       A  SARIMA  test        0    309  0.143618  6414.960209  -111.701618
# 31       B     ETS  test        0    309  0.106712  4981.780602  -182.469029
# 39       B   ARIMA  test        0    309  0.109983  5288.166760 -2154.411452
# 47       B  SARIMA  test        0    309  0.143618  6414.960209  -111.701618
#
#     MASE_mean        wQL50  under_forecast_rate
# 7    0.942027  1732.396443             0.501618
# 15   0.983000  1785.499357             0.682848
# 23   1.311272  2331.538456             0.449838
# 31   0.942027  1732.396443             0.501618
# 39   0.983000  1785.499357             0.682848
# 47   1.311272  2331.538456             0.449838
