# %% [markdown]
# # 05C Transfer Diagnostics
#
# This notebook opens transfer prediction outputs and builds diagnostics by horizon, category, and family.

# %%
from pathlib import Path
import pandas as pd
import subprocess
import sys

ROOT = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling')
REPORTS_DIR = ROOT / 'outputs' / 'reports'
SCRIPT = ROOT / 'scripts' / 'transfer_diagnostics.py'

PREDICTION_TAG = 'portable_m5_transfer_auto_capped'
PREDICTIONS = REPORTS_DIR / f'{PREDICTION_TAG}_predictions.csv'
DIAG_TAG = f'{PREDICTION_TAG}_diag'

# %% [markdown]
# ## Build Diagnostics

# %%
cmd = [
    sys.executable,
    str(SCRIPT),
    '--predictions', str(PREDICTIONS),
    '--tag', DIAG_TAG,
]
print('RUNNING', ' '.join(cmd))
subprocess.run(cmd, check=True)
# Out:
# CompletedProcess(args=['/opt/anaconda3/envs/dashboard-project/bin/python', '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts/transfer_diagnostics.py', '--predictions', '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/reports/portable_m5_transfer_auto_capped_predictions.csv', '--tag', 'portable_m5_transfer_auto_capped_diag'], returncode=0)

# %% [markdown]
# ## By Horizon

# %%
pd.read_csv(REPORTS_DIR / f'{DIAG_TAG}_by_horizon.csv')
# Out:
#           dataset                             model  horizon  n_obs      WAPE  \
# 0   M5_TRANSFER_P  XGBOOST_recent_level_auto_capped        1    840  0.097779
# 1   M5_TRANSFER_P  XGBOOST_recent_level_auto_capped        2    840  0.106817
# 2   M5_TRANSFER_P  XGBOOST_recent_level_auto_capped        3    840  0.113293
# 3   M5_TRANSFER_P  XGBOOST_recent_level_auto_capped        4    840  0.123894
# 4   M5_TRANSFER_P  XGBOOST_recent_level_auto_capped        5    840  0.124125
# 5   M5_TRANSFER_P  XGBOOST_recent_level_auto_capped        6    840  0.132086
# 6   M5_TRANSFER_P  XGBOOST_recent_level_auto_capped        7    840  0.141238
# 7   M5_TRANSFER_P  XGBOOST_recent_level_auto_capped        8    840  0.139652
# 8   M5_TRANSFER_P  XGBOOST_recent_level_auto_capped        9    840  0.146097
# 9   M5_TRANSFER_P  XGBOOST_recent_level_auto_capped       10    840  0.142293
# 10  M5_TRANSFER_P  XGBOOST_recent_level_auto_capped       11    840  0.149670
# 11  M5_TRANSFER_P  XGBOOST_recent_level_auto_capped       12    840  0.166826
#
#            RMSE         Bias  under_forecast_rate
# 0   2987.245332  -541.060592             0.598810
# 1   3292.889867  -738.712907             0
# ...[truncated]

# %% [markdown]
# ## By Category

# %%
pd.read_csv(REPORTS_DIR / f'{DIAG_TAG}_by_category.csv')
# Out:
#          dataset                             model  fg_category  n_obs  \
# 0  M5_TRANSFER_P  XGBOOST_recent_level_auto_capped      FOODS_1   1440
# 1  M5_TRANSFER_P  XGBOOST_recent_level_auto_capped      FOODS_2   1440
# 2  M5_TRANSFER_P  XGBOOST_recent_level_auto_capped      FOODS_3   1440
# 3  M5_TRANSFER_P  XGBOOST_recent_level_auto_capped    HOBBIES_1   1440
# 4  M5_TRANSFER_P  XGBOOST_recent_level_auto_capped    HOBBIES_2   1440
# 5  M5_TRANSFER_P  XGBOOST_recent_level_auto_capped  HOUSEHOLD_1   1440
# 6  M5_TRANSFER_P  XGBOOST_recent_level_auto_capped  HOUSEHOLD_2   1440
#
#        WAPE         RMSE         Bias  under_forecast_rate
# 0  0.154729  1789.899556  -543.601928             0.652083
# 1  0.171869  3813.713561 -2352.331070             0.833333
# 2  0.108926  7901.901271  -932.487763             0.504861
# 3  0.125871  1637.834540  -914.465726             0.777083
# 4  0.226776   354.020548   -47.884653             0.543750
# 5  0.149561  4353.389137 -2513.139527             0.817361
# 6  0.122436   946.719581  -340.009979             0.636111

# %% [markdown]
# ## By Family

# %%
pd.read_csv(REPORTS_DIR / f'{DIAG_TAG}_by_family.csv')
# Out:
#          dataset                             model family_bucket  n_obs  \
# 0  M5_TRANSFER_P  XGBOOST_recent_level_auto_capped         FOODS   4320
# 1  M5_TRANSFER_P  XGBOOST_recent_level_auto_capped       HOBBIES   2880
# 2  M5_TRANSFER_P  XGBOOST_recent_level_auto_capped     HOUSEHOLD   2880
#
#        WAPE         RMSE         Bias  under_forecast_rate
# 0  0.126793  5170.048202 -1276.140254             0.663426
# 1  0.135953  1184.869725  -481.175190             0.660417
# 2  0.144304  3150.259905 -1426.574753             0.726736
