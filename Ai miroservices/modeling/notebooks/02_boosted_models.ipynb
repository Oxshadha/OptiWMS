# %% [markdown]
# # 02 Boosted Models (XGBoost, CatBoost)
#
# Runs global multi-horizon models on A/B/C.

# %%
from pathlib import Path
import subprocess, sys

ROOT = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling')
cmd = [
    sys.executable, str(ROOT / 'scripts' / 'run_boosting.py'),
    '--datasets', 'A', 'B', 'C',
    '--sample-frac-c', '0.5'
]
print('Running:', ' '.join(cmd))
subprocess.run(cmd, check=True)
# Out:
# Running: /opt/anaconda3/envs/dashboard-project/bin/python /Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts/run_boosting.py --datasets A B C --sample-frac-c 0.5
# [OK] A/XGBOOST: forecasts=22248, metrics=26, inventory=103
# [OK] A/CATBOOST: forecasts=22248, metrics=26, inventory=103
# [OK] B/XGBOOST: forecasts=22248, metrics=26, inventory=103
# [OK] B/CATBOOST: forecasts=22248, metrics=26, inventory=103
# [OK] C/XGBOOST: forecasts=279720, metrics=26, inventory=795
# [OK] C/CATBOOST: forecasts=279720, metrics=26, inventory=795
# CompletedProcess(args=['/opt/anaconda3/envs/dashboard-project/bin/python', '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts/run_boosting.py', '--datasets', 'A', 'B', 'C', '--sample-frac-c', '0.5'], returncode=0)

# %%
import pandas as pd
from pathlib import Path

out = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/metrics')
files = sorted(out.glob('metrics_boosting_*_all.csv'))
print('metric files:', [f.name for f in files])
if files:
    m = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)
    display(m[(m['split']=='test') & (m['horizon']==0)].sort_values(['dataset','WAPE']).head(20))
# Out:
# metric files: ['metrics_boosting_A_all.csv', 'metrics_boosting_B_all.csv', 'metrics_boosting_C_all.csv']
#     dataset     model split  horizon   n_obs      WAPE         RMSE  \
# 51        A  CATBOOST  test        0   14832  0.116281  5337.523418
# 25        A   XGBOOST  test        0   14832  0.117375  5378.519153
# 77        B   XGBOOST  test        0   14832  0.116523  5349.681648
# 103       B  CATBOOST  test        0   14832  0.119611  5499.270616
# 155       C  CATBOOST  test        0  114480  0.178974  8385.585045
# 129       C   XGBOOST  test        0  114480  0.182465  8557.766048
#
#             Bias  MASE_mean        wQL50  under_forecast_rate
# 51  -1238.852308   1.038602  1795.501209             0.548139
# 25  -1040.790931   1.032125  1812.390244             0.573894
# 77  -1065.374571   1.025741  1799.240847             0.569512
# 103 -1244.578790   1.084185  1846.925958             0.549083
# 155 -1212.808303   1.093428  2702.876853             0.518929
# 129 -1051.732709   1.079905  2755.595559             0.529036
