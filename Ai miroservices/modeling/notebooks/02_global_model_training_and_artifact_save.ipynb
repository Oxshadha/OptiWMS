# %% [markdown]
# # 02 Global Model Training and Artifact Save
#
# This notebook trains the global models (`XGBOOST`, `CATBOOST`) on cleaned A/B/C data, evaluates them on validation and test splits, and saves model artifacts plus leaderboard outputs.

# %%
from pathlib import Path
import pandas as pd
import sys

SCRIPTS_DIR = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts')
if str(SCRIPTS_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPTS_DIR))

REPORTS_DIR = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/reports')
ARTIFACTS_DIR = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts')

# %% [markdown]
# ## Recommended Run Order
#
# Run preprocessing notebooks first so the cleaned datasets exist.

# %%
# !python "/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts/train_and_save_models.py" --datasets A B C --skip-classical --boosting-models XGBOOST CATBOOST --tag global_models
# Out:
# [OK] dataset=A model=XGBOOST forecast_rows=22248
# [OK] dataset=A model=CATBOOST forecast_rows=22248
# [OK] dataset=B model=XGBOOST forecast_rows=22248
# [OK] dataset=B model=CATBOOST forecast_rows=22248
# [OK] dataset=C model=XGBOOST forecast_rows=556200
# [OK] dataset=C model=CATBOOST forecast_rows=556200
# [OK] saved leaderboard: /Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/reports/global_models_leaderboard.csv

# %% [markdown]
# ## Leaderboard

# %%
leaderboard = pd.read_csv(REPORTS_DIR / 'global_models_leaderboard.csv')
leaderboard
# Out:
#   dataset     model split  horizon   n_obs      WAPE         RMSE  \
# 0       A  CATBOOST  test        0   14832  0.116281  5337.523418
# 1       A   XGBOOST  test        0   14832  0.117375  5378.519153
# 2       B   XGBOOST  test        0   14832  0.116523  5349.681648
# 3       B  CATBOOST  test        0   14832  0.119611  5499.270616
# 4       C  CATBOOST  test        0  222480  0.180280  8528.362570
# 5       C   XGBOOST  test        0  222480  0.184818  8730.396722
#
#           Bias  MASE_mean        wQL50  under_forecast_rate
# 0 -1238.852308   1.038602  1795.501209             0.548139
# 1 -1040.790931   1.032125  1812.390244             0.573894
# 2 -1065.374571   1.025741  1799.240847             0.569512
# 3 -1244.578790   1.084185  1846.925958             0.549083
# 4 -1329.265066   1.099196  2744.921854             0.525094
# 5 -1123.000460   1.089718  2814.026574             0.528969

# %% [markdown]
# ## Artifact Inventory

# %%
sorted(str(p) for p in ARTIFACTS_DIR.rglob('metadata.json'))[:25]
# Out:
# ['/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/catboost_h1/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/catboost_h10/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/catboost_h11/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/catboost_h12/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/catboost_h2/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/catboost_h3/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/catboost_h4/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/catboost_h5/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/catboost_h6/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/catboost_h7/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/catboost_h8/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/catboost_h9/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/xgboost_h1/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/xgboost_h10/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/xgboost_h11/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/xgboost_h12/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/xgboost_h2/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/xgboost_h3/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/xgboost_h4/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/xgboost_h5/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/xgboost_h6/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/xgboost_h7/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/xgboost_h8/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/xgboost_h9/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/B/catboost_h1/production/metadata.json']

# %% [markdown]
# ## Per-Dataset Metrics

# %%
pd.read_csv(REPORTS_DIR / 'global_models_a_metrics.csv').head()
# Out:
#   dataset    model split  horizon  n_obs      WAPE         RMSE         Bias  \
# 0       A  XGBOOST   val        1    618  0.121885  5355.007381 -1897.957357
# 1       A  XGBOOST   val        2    618  0.130412  5737.973812 -1874.453600
# 2       A  XGBOOST   val        3    618  0.138934  6274.890377 -2641.075425
# 3       A  XGBOOST   val        4    618  0.134269  5911.844895 -2266.316214
# 4       A  XGBOOST   val        5    618  0.134136  5963.619276 -2403.847959
#
#    MASE_mean        wQL50  under_forecast_rate
# 0   1.036329  1872.075360             0.684466
# 1   1.093050  2003.044340             0.619741
# 2   1.171659  2133.932841             0.708738
# 3   1.152634  2062.284881             0.684466
# 4   1.158810  2060.235332             0.694175

# %%
pd.read_csv(REPORTS_DIR / 'global_models_b_metrics.csv').head()
# Out:
#   dataset    model split  horizon  n_obs      WAPE         RMSE         Bias  \
# 0       B  XGBOOST   val        1    618  0.122563  5316.302035 -1884.286222
# 1       B  XGBOOST   val        2    618  0.130116  5819.860923 -1971.450368
# 2       B  XGBOOST   val        3    618  0.136799  6185.376424 -2616.384892
# 3       B  XGBOOST   val        4    618  0.130697  5755.015899 -2209.535767
# 4       B  XGBOOST   val        5    618  0.134145  5992.874686 -2526.668395
#
#    MASE_mean        wQL50  under_forecast_rate
# 0   1.052302  1882.483959             0.668285
# 1   1.090898  1998.493945             0.637540
# 2   1.165087  2101.134841             0.686084
# 3   1.133737  2007.414241             0.689320
# 4   1.158679  2060.376909             0.697411

# %%
pd.read_csv(REPORTS_DIR / 'global_models_c_metrics.csv').head()
# Out:
#   dataset    model split  horizon  n_obs      WAPE         RMSE         Bias  \
# 0       C  XGBOOST   val        1  27810  0.173475  8028.619355 -1077.484125
# 1       C  XGBOOST   val        2  27810  0.183701  8482.735172 -1074.896605
# 2       C  XGBOOST   val        3  27810  0.195648  9074.822313 -2125.427036
# 3       C  XGBOOST   val        4  27810  0.203240  9441.938951 -1919.531299
# 4       C  XGBOOST   val        5  27810  0.202774  9320.964493 -1977.772756
#
#    MASE_mean        wQL50  under_forecast_rate
# 0   0.973952  2632.638030             0.546746
# 1   1.031799  2787.834475             0.538511
# 2   1.097530  2969.133527             0.602769
# 3   1.139492  3084.357890             0.585617
# 4   1.141325  3077.289326             0.579720
