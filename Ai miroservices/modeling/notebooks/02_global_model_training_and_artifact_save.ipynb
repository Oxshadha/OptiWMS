# %% [markdown]
# # 02 Global Model Training and Artifact Save
#
# This notebook trains the global models (`XGBOOST`, `CATBOOST`) on cleaned A/B/C data, evaluates them on validation and test splits, and saves model artifacts plus leaderboard outputs.

# %%
from pathlib import Path
import pandas as pd
import sys

SCRIPTS_DIR = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts')
if str(SCRIPTS_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPTS_DIR))

REPORTS_DIR = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/reports')
ARTIFACTS_DIR = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts')

# %% [markdown]
# ## Recommended Run Order
#
# Run preprocessing notebooks first so the cleaned datasets exist.

# %%
# !python "/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts/train_and_save_models.py" --datasets P --skip-classical --boosting-models XGBOOST CATBOOST --tag portable_models

# %% [markdown]
# ## Leaderboard

# %%
leaderboard = pd.read_csv(REPORTS_DIR / 'portable_models_leaderboard.csv')
leaderboard
# Out:
#   dataset     model split  horizon  n_obs      WAPE         RMSE        Bias  \
# 0       P  CATBOOST  test        0  41472  0.320995  2971.725109  112.331404
# 1       P   XGBOOST  test        0  41472  0.321966  3190.205051  167.418547
#
#    MASE_mean       wQL50  under_forecast_rate
# 0   7.850909  293.190011             0.310836
# 1   1.792354  294.076896             0.352021

# %% [markdown]
# ## Artifact Inventory

# %%
sorted(str(p) for p in ARTIFACTS_DIR.rglob('metadata.json'))[:25]
# Out:
# ['/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg001/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg002/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg003/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg004/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg005/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg006/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg007/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg008/production/metadata.json',
# ...

# %% [markdown]
# ## Per-Dataset Metrics

# %%
pd.read_csv(REPORTS_DIR / 'portable_models_p_metrics.csv').head()
# Out:
#   dataset    model split  horizon  n_obs      WAPE         RMSE        Bias  \
# 0       P  XGBOOST   val        1   1728  0.315172  3303.923560  156.994658
# 1       P  XGBOOST   val        2   1728  0.352564  3661.328997  306.592097
# 2       P  XGBOOST   val        3   1728  0.321715  3156.494001  294.147638
# 3       P  XGBOOST   val        4   1728  0.332828  3213.397151  313.549655
# 4       P  XGBOOST   val        5   1728  0.349428  3267.923470  286.783460
#
#    MASE_mean       wQL50  under_forecast_rate
# 0   1.943711  291.101186             0.355903
# 1   2.315707  325.637827             0.296296
# 2   2.139545  297.144363             0.248843
# 3   1.826120  307.409251             0.250579
# 4   1.167775  322.740738             0.310764

# %%
pd.read_csv(REPORTS_DIR / 'portable_models_p_forecasts.csv').head()
# Out:
#   dataset    model series_id   fg_code   fg_category       month split  \
# 0       P  XGBOOST  RM100005  RM100005  SOLVENT_CORE  2024-08-01   val
# 1       P  XGBOOST  RM100005  RM100005  SOLVENT_CORE  2024-09-01   val
# 2       P  XGBOOST  RM100005  RM100005  SOLVENT_CORE  2024-10-01   val
# 3       P  XGBOOST  RM100005  RM100005  SOLVENT_CORE  2024-11-01   val
# 4       P  XGBOOST  RM100005  RM100005  SOLVENT_CORE  2024-12-01   val
#
#    horizon  y_true       y_pred  p10          p90
# 0        1  1092.0  1850.849121  0.0  6075.094238
# 1        1  1376.0  1230.519287  0.0  5454.764648
# 2        1  1218.0  1949.370239  0.0  6173.615234
# 3        1  1209.0  1180.363892  0.0  5404.608887
# 4        1  2034.0  1498.498657  0.0  5722.743652

# %%
pd.read_csv(REPORTS_DIR / 'portable_models_p_artifacts.csv').head()
# Out:
#   dataset    model series_id  \
# 0       P  XGBOOST        h1
# 1       P  XGBOOST        h2
# 2       P  XGBOOST        h3
# 3       P  XGBOOST        h4
# 4       P  XGBOOST        h5
#
#                                        artifact_path
# 0  /Users/k.e.oshada/Documents/OptiWMS/Ai miroser...
# 1  /Users/k.e.oshada/Documents/OptiWMS/Ai miroser...
# 2  /Users/k.e.oshada/Documents/OptiWMS/Ai miroser...
# 3  /Users/k.e.oshada/Documents/OptiWMS/Ai miroser...
# 4  /Users/k.e.oshada/Documents/OptiWMS/Ai miroser...
