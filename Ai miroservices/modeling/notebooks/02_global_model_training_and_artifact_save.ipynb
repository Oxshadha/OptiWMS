# %% [markdown]
# # 02 Global Model Training and Artifact Save
#
# This notebook trains the global models (`XGBOOST`, `CATBOOST`) on cleaned A/B/C data, evaluates them on validation and test splits, and saves model artifacts plus leaderboard outputs.

# %%
from pathlib import Path
import pandas as pd
import sys

SCRIPTS_DIR = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts')
if str(SCRIPTS_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPTS_DIR))

REPORTS_DIR = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/reports')
ARTIFACTS_DIR = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts')

# %% [markdown]
# ## Recommended Run Order
#
# Run preprocessing notebooks first so the cleaned datasets exist.

# %%
# !python "/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts/train_and_save_models.py" --datasets A B C --skip-classical --boosting-models XGBOOST CATBOOST --tag global_models
# Out:
# [OK] dataset=A model=ETS failed_series=0 forecast_rows=1854
# [OK] dataset=A model=ARIMA failed_series=0 forecast_rows=1854
# [OK] dataset=A model=SARIMA failed_series=0 forecast_rows=1854
# [OK] dataset=A model=XGBOOST forecast_rows=22248
# [OK] dataset=A model=CATBOOST forecast_rows=22248
# [OK] dataset=B model=ETS failed_series=0 forecast_rows=1854
# [OK] dataset=B model=ARIMA failed_series=0 forecast_rows=1854
# [OK] dataset=B model=SARIMA failed_series=0 forecast_rows=1854
# [OK] dataset=B model=XGBOOST forecast_rows=22248
# [OK] dataset=B model=CATBOOST forecast_rows=22248
# [OK] dataset=C model=ETS failed_series=0 forecast_rows=111240
# [OK] dataset=C model=ARIMA failed_series=0 forecast_rows=111240
# [OK] dataset=C model=SARIMA failed_series=0 forecast_rows=111240
# [OK] dataset=C model=XGBOOST forecast_rows=556200
# [OK] dataset=C model=CATBOOST forecast_rows=556200
# [OK] saved leaderboard: /Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/reports/ds_workflow_leaderboard.csv

# %% [markdown]
# ## Leaderboard

# %%
leaderboard = pd.read_csv(REPORTS_DIR / 'global_models_leaderboard.csv')
leaderboard
# Out:
#    dataset     model split  horizon   n_obs          WAPE          RMSE  \
# 0        A     ARIMA  test        0    1236  1.066327e-01  4.788504e+03
# 1        A  CATBOOST  test        0   14832  1.162810e-01  5.337523e+03
# 2        A   XGBOOST  test        0   14832  1.173748e-01  5.378519e+03
# 3        A       ETS  test        0    1236  1.182009e-01  5.550639e+03
# 4        A    SARIMA  test        0    1236  2.173242e-01  1.382771e+04
# 5        B     ARIMA  test        0    1236  1.066327e-01  4.788504e+03
# 6        B   XGBOOST  test        0   14832  1.165232e-01  5.349682e+03
# 7        B       ETS  test        0    1236  1.182009e-01  5.550639e+03
# 8        B  CATBOOST  test        0   14832  1.196114e-01  5.499271e+03
# 9        B    SARIMA  test        0    1236  2.173242e-01  1.382771e+04
# 10       C  CATBOOST  test        0  222480  1.802798e-01  8.528363e+03
# 11       C   XGBOOST  test        0  222480  1.848185e-01  8.730397e+03
# 12       C     ARIMA  test        0   74160  1.882291e-01  9.067764e+03
# 13       C       ETS  test        0   74160  2.041341e-01  1.106234e+04
# 14       C    SARIMA  test        0   74160  2.358079e+10  1.999774e+17
#
#             Bias     MASE_mean         wQL50  under_forecast_rate
# 0  -3.008365e+02  9.522145e-01  1.646522e+03             0.521845
# 1  -1.238852e+03  1.038602e+00  1.795501e+03             0.548139
# 2  -1.040791e+03  1.032125e+00  1.812390e+03             0.573894
# 3  -1.956369e+02  1.037084e+00  1.825147e+03             0.530744
# 4   5.540652e+02  1.953624e+00  3.355715e+03             0.444984
# 5  -3.008365e+02  9.522145e-01  1.646522e+03             0.521845
# 6  -1.065375e+03  1.025741e+00  1.799241e+03             0.569512
# 7  -1.956369e+02  1.037084e+00  1.825147e+03             0.530744
# 8  -1.244579e+03  1.084185e+00  1.846926e+03             0.549083
# 9   5.540652e+02  1.953624e+00  3.355715e+03             0.444984
# 10 -1.329265e+03  1.099196e+00  2.744922e+03             0.525094
# 11 -1.123000e+03  1.089718e+00  2.814027e+03             0.528969
# 12  2.269871e+02  1.098162e+00  2.939634e+03             0.473139
# 13 -2.974416e+01  1.156628e+00  3.188026e+03             0.501699
# 14  7.365373e+14  1.173730e+11  3.682686e+14             0.433563

# %% [markdown]
# ## Artifact Inventory

# %%
sorted(str(p) for p in ARTIFACTS_DIR.rglob('metadata.json'))[:25]
# Out:
# ['/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg001/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg002/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg003/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg004/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg005/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg006/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg007/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg008/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg009/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg010/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg011/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg012/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg013/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg014/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg015/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg016/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg017/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg018/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg019/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg020/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg021/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg022/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg023/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg024/production/metadata.json',
#  '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/artifacts/A/arima_fg025/production/metadata.json']

# %% [markdown]
# ## Per-Dataset Metrics

# %%
pd.read_csv(REPORTS_DIR / 'global_models_a_metrics.csv').head()
# Out:
#   dataset model split  horizon  n_obs      WAPE         RMSE         Bias  \
# 0       A   ETS   val        1    103  0.106033  4338.880526  1290.401337
# 1       A   ETS   val        2    103  0.091652  3796.748621   -81.702897
# 2       A   ETS   val        3    103  0.119636  5017.963034  -592.214897
# 3       A   ETS   val        4    103  0.104865  4871.055926 -1967.018160
# 4       A   ETS   val        5    103  0.157099  7265.007619 -3902.685500
#
#    MASE_mean        wQL50  under_forecast_rate
# 0   0.858919  1500.984630             0.398058
# 1   0.848642  1363.028451             0.485437
# 2   1.010401  1813.327238             0.601942
# 3   0.964295  1664.670030             0.640777
# 4   1.452651  2650.603120             0.757282

# %%
pd.read_csv(REPORTS_DIR / 'global_models_b_metrics.csv').head()
# Out:
#   dataset model split  horizon  n_obs      WAPE         RMSE         Bias  \
# 0       B   ETS   val        1    103  0.106033  4338.880526  1290.401337
# 1       B   ETS   val        2    103  0.091652  3796.748621   -81.702897
# 2       B   ETS   val        3    103  0.119636  5017.963034  -592.214897
# 3       B   ETS   val        4    103  0.104865  4871.055926 -1967.018160
# 4       B   ETS   val        5    103  0.157099  7265.007619 -3902.685500
#
#    MASE_mean        wQL50  under_forecast_rate
# 0   0.858919  1500.984630             0.398058
# 1   0.848642  1363.028451             0.485437
# 2   1.010401  1813.327238             0.601942
# 3   0.964295  1664.670030             0.640777
# 4   1.452651  2650.603120             0.757282

# %%
pd.read_csv(REPORTS_DIR / 'global_models_c_metrics.csv').head()
# Out:
#   dataset model split  horizon  n_obs      WAPE          RMSE         Bias  \
# 0       C   ETS   val        1   6180  0.189809   7926.830573  1956.627805
# 1       C   ETS   val        2   6180  0.186143   8090.080091   226.140668
# 2       C   ETS   val        3   6180  0.207482   9426.979889  -924.154300
# 3       C   ETS   val        4   6180  0.209396  10212.136114 -3204.643340
# 4       C   ETS   val        5   6180  0.264132  13684.160812 -5931.600208
#
#    MASE_mean        wQL50  under_forecast_rate
# 0   0.903221  2516.863602             0.356958
# 1   0.996890  2620.766235             0.464563
# 2   1.103454  3031.125216             0.547087
# 3   1.226024  3289.141921             0.656958
# 4   1.642800  4498.458114             0.750000
