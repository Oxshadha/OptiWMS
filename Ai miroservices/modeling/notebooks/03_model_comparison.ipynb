# %% [markdown]
# # 03 Model Comparison and Dashboard Outputs
#
# Aggregates all model outputs and creates dashboard-ready tables.

# %%
from pathlib import Path
import subprocess, sys

ROOT = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling')
cmd = [sys.executable, str(ROOT / 'scripts' / 'compare_models.py')]
print('Running:', ' '.join(cmd))
subprocess.run(cmd, check=True)
# Out:
# Running: /opt/anaconda3/envs/dashboard-project/bin/python /Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts/compare_models.py
# Saved report files in /Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/reports
# Leaderboard rows: 12
# CompletedProcess(args=['/opt/anaconda3/envs/dashboard-project/bin/python', '/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts/compare_models.py'], returncode=0)

# %%
import pandas as pd
from pathlib import Path

rep = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/outputs/reports')
for f in sorted(rep.glob('*.csv')):
    print(f.name)

lb = pd.read_csv(rep / 'leaderboard_top5_per_dataset.csv')
display(lb.sort_values(['dataset', 'WAPE']))

byh = pd.read_csv(rep / 'test_metrics_by_horizon.csv')
display(byh.sort_values(['dataset', 'horizon', 'WAPE']).head(30))
# Out:
# all_metrics_combined.csv
# dashboard_forecast_output.csv
# dashboard_inventory_recommendations.csv
# leaderboard_top5_per_dataset.csv
# manager_inventory_priority_top200.csv
# manager_model_summary.csv
# manager_risk_summary.csv
# test_metrics_by_horizon.csv
#    dataset     model split  horizon     n_obs      WAPE          RMSE  \
# 0        A     ARIMA  test        0    1236.0  0.106633   4788.503914
# 1        A  CATBOOST  test        0   14832.0  0.116281   5337.523418
# 2        A   XGBOOST  test        0   14832.0  0.117375   5378.519153
# 3        A       ETS  test        0    1236.0  0.118201   5550.638967
# 4        A    SARIMA  test        0    1236.0  0.217324  13827.714808
# 5        B     ARIMA  test        0    1236.0  0.106633   4788.503914
# 6        B   XGBOOST  test        0   14832.0  0.116523   5349.681648
# 7        B       ETS  test        0    1236.0  0.118201   5550.638967
# 8        B  CATBOOST  test        0   14832.0  0.119611   5499.270616
# 9        B    SARIMA  test        0    1236.0  0.217324  13827.714808
# 10       C  CATBOOST  test        0  114480.0  0.178974   8385.585045
# 11       C   XGBOOST  test        0  114480.0  0.182465   8557.766048
#
#            Bias  MASE_mean        wQL50  under_forecast_rate
# 0   -300.836483   0.952214  1646.522179             0.521845
# 1  -1238.852308   1.038602  1795.501209             0.548139
# 2  -1040.790931   1.032125  1812.390244             0.573894
# 3   -195.636864   1.037084  1825.146777             0.530744
# 4    554.065186   1.953624  3355.715065             0.444984
# 5   -300.836483   0.952214  1646.522179             0.521845
# 6  -1065.374571   1.025741  1799.240847             0.569512
# 7   -195.636864   1.037084  1825.146777             0.530744
# 8  -1244.578790   1.084185  1846.925958             0.549083
# 9    554.065186   1.953624  3355.715065             0.444984
# 10 -1212.808303   1.093428  2702.876853             0.518929
# 11 -1051.732709   1.079905  2755.595559             0.529036
#    dataset     model  horizon      WAPE  MASE_mean          RMSE         Bias  \
# 0        A     ARIMA        0  0.106633   0.952214   4788.503914  -300.836483
# 13       A  CATBOOST        0  0.116281   1.038602   5337.523418 -1238.852308
# 52       A   XGBOOST        0  0.117375   1.032125   5378.519153 -1040.790931
# 26       A       ETS        0  0.118201   1.037084   5550.638967  -195.636864
# 39       A    SARIMA        0  0.217324   1.953624  13827.714808   554.065186
# 1        A     ARIMA        1  0.103134   0.952410   4538.734715   507.415648
# 53       A   XGBOOST        1  0.107724   0.967553   4911.968428 -1036.136509
# 14       A  CATBOOST        1  0.110144   0.991505   5076.558607 -1422.855854
# 27       A       ETS        1  0.141300   1.167630   6191.272928   434.751086
# 40       A    SARIMA        1  0.181233   1.466635   7924.357120  1374.419096
# 2        A     ARIMA        2  0.085931   0.794905   3869.237750  -209.830206
# 28       A       ETS        2  0.101352   0.919127   4707.848236  -366.914669
# 54       A   XGBOOST        2  0.110110   0.992027   5021.087049  -738.552790
# 15       A  CATBOOST        2  0.115816   1.048508   5346.613477 -1439.259573
# 41       A    SARIMA        2  0.153469   1.405625   6672.973976   182.238709
# 3        A     ARIMA        3  0.105753   0.964783   4988.954718 -1346.615286
# 29       A       ETS        3  0.112635   1.101960   5145.643140   177.789320
# 16       A  CATBOOST        3  0.122155   1.051432   5651.137133 -2088.695405
# 55       A   XGBOOST        3  0.122294   1.068027   5650.950675 -1935.655661
# 42       A    SARIMA        3  0.163474   1.645398   7532.918616   811.671379
# 4        A     ARIMA        4  0.109936   0.883611   5040.740047    74.947733
# 56       A   XGBOOST        4  0.119941   1.066207   5538.596287 -1815.474949
# 30       A       ETS        4  0.121518   0.977096   5839.799512 -1075.705078
# 17       A  CATBOOST        4  0.124635   1.069758   5741.051018 -2223.971668
# 43       A    SARIMA        4  0.165220   1.408337   7708.931921  -588.789461
# 5        A     ARIMA        5  0.109124   0.936320   4374.610610  1654.140664
# 31       A       ETS        5  0.115314   0.966348   4906.963888   452.053698
# 57       A   XGBOOST        5  0.122633   1.087366   5650.078364 -2026.458166
# 18       A  CATBOOST        5  0.129700   1.113238   6017.969664 -2376.460122
# 44       A    SARIMA        5  0.195625   1.741337   9160.539786   201.355073
#
#     under_forecast_rate
# 0              0.521845
# 13             0.548139
# 52             0.573894
# 26             0.530744
# 39             0.444984
# 1              0.427184
# 53             0.583333
# 14             0.580097
# 27             0.504854
# 40             0.407767
# 2              0.524272
# 28             0.543689
# 54             0.527508
# 15             0.562298
# 41             0.466019
# 3              0.582524
# 29             0.504854
# 16             0.631877
# 55             0.635922
# 42             0.407767
# 4              0.533981
# 56             0.644822
# 30             0.582524
# 17             0.654531
# 43             0.504854
# 5              0.339806
# 31             0.485437
# 57             0.653722
# 18             0.639968
# 44             0.427184
