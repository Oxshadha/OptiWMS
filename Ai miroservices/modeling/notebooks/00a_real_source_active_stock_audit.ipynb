# %% [markdown]
# # 00a Real Source Active Stock Audit
#
# This notebook inspects the real Excel workbook used as the seed for synthetic forecasting data and exports a canonical `Active stock` base table.

# %%
from pathlib import Path
import json
import pandas as pd
import sys

SCRIPTS_DIR = Path('/Users/k.e.oshada/Documents/OptiWMS/Ai miroservices/modeling/scripts')
if str(SCRIPTS_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPTS_DIR))

from real_source_extraction import (
    REAL_SOURCE_FILE,
    REAL_SOURCE_SHEET,
    REAL_OUT_DIR,
    extract_active_stock_canonical,
    build_active_stock_summary,
    export_active_stock_outputs,
    load_active_stock_raw,
)

# %% [markdown]
# ## Workbook Overview

# %%
xlsx = pd.ExcelFile(REAL_SOURCE_FILE)
xlsx.sheet_names

# %% [markdown]
# ## Raw Active Stock Preview

# %%
raw_active_stock = load_active_stock_raw()
raw_active_stock.head(10)

# %% [markdown]
# ## Canonical Extract

# %%
active_stock = extract_active_stock_canonical()
active_stock.head(20)

# %% [markdown]
# ## Summary

# %%
summary = build_active_stock_summary(active_stock)
summary

# %% [markdown]
# ## Export Canonical Base Table

# %%
csv_path, summary_path = export_active_stock_outputs(active_stock, summary)
csv_path, summary_path

# %% [markdown]
# ## Reload Saved Output

# %%
pd.read_csv(REAL_OUT_DIR / 'active_stock_canonical.csv').head(20)
